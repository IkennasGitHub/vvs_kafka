# %%
arrivals = get_departures(Station.VAIHINGEN, limit=10)

for arrival in arrivals:
    if arrival.cancelled:
        print(f"Alarm! The train at {arrival.real_datetime} has been cancelled!")
        # Check arrival.stop_infos and arrival.line_infos for more information

# %%
print(Station.__members__.values())
# Out:
# dict_values([<Station.WALDBURGSTRASSE_1: 'de:08111:2:0:3'>, <Station.WALDBURGSTRASSE_2: 'de:08111:2:0:4'>, <Station.WALDBURGSTRASSE_3: 'de:08115:4675:0:3'>, <Station.WALDBURGSTRASSE_4: 'de:08115:4675:0:4'>, <Station.FAUSTSTRASSE: 'de:08111:5'>, <Station.FAUSTSTRASSE_1: 'de:08111:5:1:1'>, <Station.FAUSTSTRASSE_2: 'de:08111:5:1:2'>, <Station.FAUSTSTRASSE_3: 'de:08111:5:3:5'>, <Station.VAIHINGEN_VIADUKT: 'de:08111:6'>, <Station.VAIHINGEN_VIADUKT_1: 'de:08111:6:1:1'>, <Station.VAIHINGEN_VIADUKT_2: 'de:08111:6:1:2'>, <Station.ENGELBOLDSTRASSE: 'de:08111:8'>, <Station.ENGELBOLDSTRASSE_1: 'de:08111:8:1:1'>, <Station.ENGELBOLDSTRASSE_2: 'de:08111:8:1:2'>, <Station.ENGELBOLDSTRASSE_3: 'de:08111:8:3:5'>, <Station.SÜDHEIMER_PLATZ: 'de:08111:13'>, <Station.SÜDHEIMER_PLATZ_1: 'de:08111:13:1:1'>, <Station.SÜDHEIMER_PLATZ_2: 'de:08111:13:2:2'>, <Station.SÜDHEIMER_PLATZ_3: 'de:08111:13:3:3'>, <Station.SÜDHEIMER_PLATZ_4: 'de:08111:13:4:4'>, <Station.BIHLPLATZ: 'de:08111:15'>, <Station.BIHLPLATZ_1: 'de:08111:15:0:1'>, <Station.BIHLPLATZ_2: 'de:08111:15:0:2'>, <Station.NECKARTOR: 'de:08111:25'>, <Station.NECKARTOR_1: 'de:08111:25:0:1'>, <Station.NECKARTOR_2: 'de:08111:25:0:2'>, <Station.NECKARTOR_3: 'de:08111:25:0:4'>, <Station.STÖCKACH: 'de:08111:26'>, <Station.STÖCKACH_1: 'de:08111:26:1:1'>, <Station.STÖCKACH_2: 'de:08111:26:2:2'>, <Station.STÖCKACH_3: 'de:08111:26:3:4'>, <Station.METZSTRASSE: 'de:08111:27'>, <Station.METZSTRASSE_1: 'de:08111:27:0:1'>, <Station.METZSTRASSE_2: 'de:08111:27:0:2'>, <Station.MINERALBÄDER: 'de:08111:28'>, <Station.MINERALBÄDER_1: 'de:08111:28:1:1'>, <Station.MINERALBÄDER_2: 'de:08111:28:1:2'>, <Station.MERCEDESSTRASSE_1: 'de:08111:30:0:1'>, <Station.MERCEDESSTRASSE_2: 'de:08111:30:0:2'>, <Station.MERCEDESSTRASSE_3: 'de:08118:6491:0:3'>, <Station.MERCEDESSTRASSE_4: 'de:08118:6491:0:4'>, <Station.UFF_KIRCHHOF: 'de:08111:32'>, <Station.UFF_KIRCHHOF_1: 'de:08111:32:1:2'>, <Station.UFF_KIRCHHOF_2: 'de:08111:32:2:1'>, <Station.UFF_KIRCHHOF_3: 'de:08111:32:3:3'>, <Station.AUGSBURGER_PLATZ: 'de:08111:33'>, <Station.AUGSBURGER_PLATZ_1: 'de:08111:33:1:1'>, <Station.AUGSBURGER_PLATZ_2: 'de:08111:33:2:2'>, <Station.AUGSBURGER_PLATZ_3: 'de:08111:33:5:3'>, <Station.NÜRNBERGER_STRASSE: 'de:08111:34'>, <Station.NÜRNBERGER_STRASSE_1: 'de:08111:34:1:1'>, <Station.NÜRNBERGER_STRASSE_2: 'de:08111:34:1:2'>, <Station.NÜRNBERGER_STRASSE_3: 'de:08111:34:2:3'>, <Station.NÜRNBERGER_STRASSE_4: 'de:08111:34:2:4'>, <Station.NÜRNBERGER_STRASSE_5: 'de:08111:34:3:1'>, <Station.NÜRNBERGER_STRASSE_6: 'de:08111:34:4:2'>, <Station.NÜRNBERGER_STRASSE_7: 'de:08111:34:5:3'>, <Station.NÜRNBERGER_STRASSE_8: 'de:08111:34:5:7'>, <Station.NÜRNBERGER_STRASSE_9: 'de:08111:34:7:10'>, <Station.ANTWERPENER_STRASSE: 'de:08111:35'>, <Station.ANTWERPENER_STRASSE_1: 'de:08111:35:1:1'>, <Station.ANTWERPENER_STRASSE_2: 'de:08111:35:1:2'>, <Station.ANTWERPENER_STRASSE_3: 'de:08111:35:2:3'>, <Station.BESKIDENSTRASSE: 'de:08111:36'>, <Station.BESKIDENSTRASSE_1: 'de:08111:36:1:1'>, <Station.BESKIDENSTRASSE_2: 'de:08111:36:2:2'>, <Station.BESKIDENSTRASSE_3: 'de:08111:36:3:3'>, <Station.FELLBACH_HÖHENSTRASSE: 'de:08119:37'>, <Station.FELLBACH_HÖHENSTRASSE_1: 'de:08119:37:0:1'>, <Station.FELLBACH_HÖHENSTRASSE_2: 'de:08119:37:0:2'>, <Station.FELLBACH_HÖHENSTRASSE_3: 'de:08119:37:0:3'>, <Station.FELLBACH_HÖHENSTRASSE: 'de:08119:37'>, <Station.FELLBACH_HÖHENSTRASSE_1: 'de:08119:37:0:1'>, <Station.FELLBACH_HÖHENSTRASSE_2: 'de:08119:37:0:2'>, <Station.FELLBACH_HÖHENSTRASSE_3: 'de:08119:37:0:3'>, <Station.ESSLINGER_STRASSE_1: 'de:08119:38:1:1'>, <Station.ESSLINGER_STRASSE_2: 'de:08119:38:1:2'>, <Station.ESSLINGER_STRASSE_3: 'de:08119:38:2:3'>, <Station.ESSLINGER_STRASSE_4: 'de:08119:38:2:4'>, <Station.ESSLINGER_STRASSE_5: 'de:08116:2918:0:3'>, <Station.ESSLINGER_STRASSE_6: 'de:08116:2918:0:4'>, <Station.ESSLINGER_STRASSE_7: 'de:08116:4054:0:3'>, <Station.ESSLINGER_STRASSE_8: 'de:08116:4054:0:4'>, <Station.ESSLINGER_STRASSE_9: 'de:08116:5007:0:3'>, <Station.ESSLINGER_STRASSE_10: 'de ...

# %%
station_list = list(Station.__members__.values())
for station in station_list:
    print(station.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 station_list = list(Station.__members__.values())
#       2 for station in station_list:
#       3     print(station.name)
#
# NameError: name 'Station' is not defined

# %%
from vvspy import get_departures
from vvspy.enums import Station

deps = get_departures(Station.HAUPTBF__ARNULF_KLETT_PLATZ_1, limit=30)
for dep in deps:
    if dep.delay > 0:
        print("Alarm! Delay detected.")
        print(dep)  # [Delayed] [11:47] [RB17]: Stuttgart Hauptbahnhof (oben) - Pforzheim Hauptbahnhof

    else:
        print(f"Train on time: {dep.real_datetime}")
        print(dep)  # [11:47] [RB17]: Stuttgart Hauptbahnhof (oben) - Pforzheim Hauptbahnhof
# Out:
# Train on time: 2024-08-19 20:11:00
# [20:11] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 20:13:00
# [20:13] [U15]: Stammheim - Heumaden
# Train on time: 2024-08-19 20:15:00
# [20:15] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 20:19:00
# [20:19] [U7]: Mönchfeld - Ostfildern Nellingen
# Train on time: 2024-08-19 20:21:00
# [20:21] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 20:23:00
# [20:23] [U15]: Stammheim - Ruhbank
# Train on time: 2024-08-19 20:25:00
# [20:25] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 20:30:00
# [20:30] [U7]: Mönchfeld - Ostfildern Nellingen
# Train on time: 2024-08-19 20:32:00
# [20:32] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 20:35:00
# [20:35] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 20:36:00
# [20:36] [U15]: Stammheim - Ruhbank
# Train on time: 2024-08-19 20:37:00
# [20:37] [U7]: Mönchfeld - SSB-Zentrum
# Train on time: 2024-08-19 20:42:00
# [20:42] [U15]: Stammheim - SSB-Zentrum
# Train on time: 2024-08-19 20:45:00
# [20:45] [U7]: Mönchfeld - Ostfildern Nellingen
# Train on time: 2024-08-19 20:45:00
# [20:45] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 20:47:00
# [20:47] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 20:51:00
# [20:51] [U15]: Stammheim - Ruhbank
# Train on time: 2024-08-19 20:55:00
# [20:55] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 21:00:00
# [21:00] [U7]: Mönchfeld - Ostfildern Nellingen
# Train on time: 2024-08-19 21:02:00
# [21:02] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 21:04:00
# [21:04] [U7]: Mönchfeld - SSB-Zentrum
# Train on time: 2024-08-19 21:06:00
# [21:06] [U15]: Stammheim - Ruhbank
# Train on time: 2024-08-19 21:08:00
# [21:08] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 21:15:00
# [21:15] [U7]: Mönchfeld - Ostfildern Nellingen
# Train on time: 2024-08-19 21:17:00
# [21:17] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 21:21:00
# [21:21] [U15]: Stammheim - Ruhbank
# Train on time: 2024-08-19 21:23:00
# [21:23] [U6]: Gerlingen - Flughafen/Messe
# Train on time: 2024-08-19 21:30:00
# [21:30] [U7]: Mönchfeld - Ostfildern Nellingen
# Train on time: 2024-08-19 21:32:00
# [21:32] [U12]: Neckargröningen Remseck - Dürrlewang
# Train on time: 2024-08-19 21:34:00
# [21:34] [U7]: Mönchfeld - SSB-Zentrum

# %%
from vvspy import get_departures
import json
from vvspy.enums import Station
from datetime import datetime, timedelta
import vvspy.enums
from multiprocessing import Process

#f = open("realtime_data.csv", "a")
#station_list = filtered_ids #list(Station.__members__.values())

zone_list = []
sttn_list = list(Station.__members__.values())
for index in range(len(sttn_list)):
    if sttn_list[index].value in filtered_ids:
        zone_list.append(sttn_list[index])

current_time = datetime.now()
requested_time = current_time - timedelta(hours=6)
stop_time = requested_time + timedelta(hours=1)

def process_range(start_index, end_index):
    for index in range(start_index, end_index):
        if index >= len(zone_list):
            break

    #for index in range(200):
        
        deps = get_departures(zone_list[index], limit=20, check_time=requested_time)
        print(f"Current iteration: {zone_list[index].name}, index: {index}")
            
        for dep in deps:
            if dep.real_datetime < stop_time:
                if dep.serving_line.symbol in ("S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10", "U1", "U2", "U3", "U4", "U5", "U6", "U7", "U8", "U9", "U10", "U11", "U12", "U13", "U14"):
                    if dep.delay > 0:
                        print(f"Alarm! Delay detected at {zone_list[index].name}")
                        print(dep)
                
                        #f.write(f'{dep.serving_line}; {dep.delay}\n')
                        print(f'There will be a {dep.delay} minutes delay at {zone_list[index].name}')
                    elif dep.cancelled:
                        print(f"Alarm! The train at {dep.real_datetime} has been cancelled!")
                    else:
                        print(f"Train on time at {zone_list[index].name}")
                        print(dep.real_datetime.strftime('%H:%M'))
                        #continue
                else:
                    continue
            else:
                continue

if __name__ == '__main__':
    # Define the ranges for different processes
    ranges = [(0, 400), (400, 900)]

    # Create a list of processes
    '''processes = []
    for start, end in ranges:
        p = multiprocessing.Process(target=process_range, args=(start, end))
        processes.append(p)
    
    # Start all processes
    for p in processes:
        p.start()
    
    # Wait for all processes to finish
    for p in processes:
        p.join()
''' 
    process_1 = Process(target=process_range, args=(0, 100))
    process_2 = Process(target=process_range, args=(100, 200))

    process_1.start()
    process_2.start()

    process_1.join()
    process_2.join()
    
    print("Processing complete.")
# Out:
# Processing complete.

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
# Replace 'your_file.csv' with the actual path to your CSV file
df = pd.read_csv('vvs_steige.csv', delimiter=';', encoding='latin1')

# Extract 'Globale ID' where 'Tarifzonen' is 1
filtered_ids = df[df['Tarifzonen'] == '1']['Globale ID'].tolist()

# Print the list of filtered IDs
print(filtered_ids)
# Out:
# ['de:08111:2:0:3', 'de:08111:2:0:4', 'de:08111:5:1:1', 'de:08111:5:1:2', 'de:08111:5:3:5', 'de:08111:6:1:1', 'de:08111:6:1:2', 'de:08111:8:1:1', 'de:08111:8:1:2', 'de:08111:8:3:5', 'de:08111:13:1:1', 'de:08111:13:2:2', 'de:08111:13:3:3', 'de:08111:13:4:4', 'de:08111:15:0:1', 'de:08111:15:0:2', 'de:08111:25:0:1', 'de:08111:25:0:2', 'de:08111:25:0:4', 'de:08111:26:1:1', 'de:08111:26:2:2', 'de:08111:26:3:4', 'de:08111:27:0:1', 'de:08111:27:0:2', 'de:08111:28:1:1', 'de:08111:28:1:2', 'de:08111:30:0:1', 'de:08111:30:0:2', 'de:08111:32:1:2', 'de:08111:32:2:1', 'de:08111:32:3:3', 'de:08111:33:1:1', 'de:08111:33:2:2', 'de:08111:33:5:3', 'de:08111:34:1:1', 'de:08111:34:1:2', 'de:08111:34:2:3', 'de:08111:34:2:4', 'de:08111:34:3:1', 'de:08111:34:4:2', 'de:08111:34:5:3', 'de:08111:34:5:7', 'de:08111:34:7:10', 'de:08111:35:1:1', 'de:08111:35:1:2', 'de:08111:35:2:3', 'de:08111:36:1:1', 'de:08111:36:2:2', 'de:08111:36:3:3', 'de:08111:43:0:1', 'de:08111:43:0:2', 'de:08111:43:0:4', 'de:08111:43:0:5', 'de:08111:43:0:7', 'de:08111:55:1:2', 'de:08111:55:2:1', 'de:08111:55:3:4', 'de:08111:55:4:5', 'de:08111:69:0:3', 'de:08111:70:0:3', 'de:08111:76:1:1', 'de:08111:76:1:2', 'de:08111:76:1:4', 'de:08111:77:0:1', 'de:08111:77:0:2', 'de:08111:77:0:4', 'de:08111:78:1:1', 'de:08111:78:1:2', 'de:08111:78:2:4', 'de:08111:79:0:1', 'de:08111:79:0:2', 'de:08111:80:1:1', 'de:08111:80:1:2', 'de:08111:80:1:3', 'de:08111:80:1:4', 'de:08111:80:2:7', 'de:08111:80:2:8', 'de:08111:81:1:1', 'de:08111:81:2:2', 'de:08111:81:2:4', 'de:08111:81:3:3', 'de:08111:82:0:1', 'de:08111:82:0:2', 'de:08111:82:0:3', 'de:08111:82:0:4', 'de:08111:83:0:1', 'de:08111:83:0:2', 'de:08111:83:0:3', 'de:08111:84:1:7', 'de:08111:84:1:8', 'de:08111:84:2:1', 'de:08111:84:2:2', 'de:08111:86:1:3', 'de:08111:86:1:4', 'de:08111:87:0:3', 'de:08111:87:0:4', 'de:08111:104:0:1', 'de:08111:104:0:2', 'de:08111:104:0:5', 'de:08111:106:1:6', 'de:08111:106:2:7', 'de:08111:106:3:3', 'de:08111:106:4:4', 'de:08111:106:5:5', 'de:08111:107:1:1', 'de:08111:107:1:2', 'de:08111:107:2:3', 'de:08111:107:2:4', 'de:08111:108:1:1', 'de:08111:108:1:2', 'de:08111:108:2:4', 'de:08111:108:2:5', 'de:08111:109:0:3', 'de:08111:109:0:4', 'de:08111:110:0:1', 'de:08111:110:0:2', 'de:08111:110:0:3', 'de:08111:111:0:1', 'de:08111:111:0:2', 'de:08111:111:0:3', 'de:08111:112:0:1', 'de:08111:112:0:2', 'de:08111:112:0:3', 'de:08111:115:1:1', 'de:08111:115:1:2', 'de:08111:123:0:1', 'de:08111:123:0:2', 'de:08111:123:0:3', 'de:08111:124:0:1', 'de:08111:124:0:2', 'de:08111:124:0:3', 'de:08111:125:0:1', 'de:08111:125:0:2', 'de:08111:125:0:3', 'de:08111:125:0:5', 'de:08111:126:1:1', 'de:08111:126:1:2', 'de:08111:126:1:3', 'de:08111:129:1:1', 'de:08111:129:1:2', 'de:08111:129:2:3', 'de:08111:130:1:1', 'de:08111:130:1:2', 'de:08111:146:1:1', 'de:08111:146:1:2', 'de:08111:146:2:4', 'de:08111:147:1:1', 'de:08111:147:1:2', 'de:08111:147:2:4', 'de:08111:148:1:1', 'de:08111:148:1:2', 'de:08111:148:2:4', 'de:08111:150:0:4', 'de:08111:151:1:1', 'de:08111:151:1:2', 'de:08111:151:2:4', 'de:08111:152:1:1', 'de:08111:152:2:2', 'de:08111:153:1:1', 'de:08111:153:1:2', 'de:08111:153:3:4', 'de:08111:153:3:5', 'de:08111:154:1:1', 'de:08111:154:2:2', 'de:08111:154:3:3', 'de:08111:154:3:4', 'de:08111:154:3:5', 'de:08111:154:3:6', 'de:08111:156:0:3', 'de:08111:158:1:1', 'de:08111:158:2:2', 'de:08111:158:3:3', 'de:08111:158:4:4', 'de:08111:159:1:1', 'de:08111:159:1:2', 'de:08111:161:0:3', 'de:08111:161:0:4', 'de:08111:162:0:3', 'de:08111:162:0:4', 'de:08111:163:1:1', 'de:08111:163:1:2', 'de:08111:163:2:3', 'de:08111:163:2:4', 'de:08111:164:0:3', 'de:08111:164:0:4', 'de:08111:165:1:1', 'de:08111:165:1:2', 'de:08111:165:1:3', 'de:08111:165:1:4', 'de:08111:170:1:1', 'de:08111:170:2:2', 'de:08111:170:3:3', 'de:08111:183:0:1', 'de:08111:183:0:2', 'de:08111:211:0:1', 'de:08111:211:0:2', 'de:08111:211:0:6', 'de:08111:212:1:1', 'de:08111:212:1:2', 'de:08111:212:3:3', 'de:08111:212:3:4', 'de:08111:215:0:3', 'de:08111:215:0:4', 'de:08111:216:1:1', 'de:08111:216:1:2', 'de: ...

# %%
zone_list = []
sttn_list = list(Station.__members__.values())
for index in range(len(sttn_list)):
    if sttn_list[index].value in filtered_ids:
        zone_list.append(sttn_list[index])

print(len(zone_list))
# Out:
# 1240

# %%
from datetime import datetime, timedelta

now = datetime.now()
diff_time = now - timedelta(minutes = 3)

print(f'{now}, and\n{diff_time}')
# Out:
# 2024-08-22 17:05:07.622851, and
# 2024-08-22 17:02:07.622851
